# %%
import os
import sys
import random
import math
import re
import time
import numpy as np
import cv2
import matplotlib
import matplotlib.pyplot as plt
from PIL import Image
from scipy import ndimage, misc
N='410'
a=Image.open('/Users/sofiadunlosky/Downloads/ilovepdf_images-extracted/img'+N+'.jpg')

# %%
from imagenet import classify_image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-51a3920cd162> in <module>
# ----> 1 from imagenet import classify_image
#
# ModuleNotFoundError: No module named 'imagenet'

# %%
a
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=337x362 at 0x12782A240>

# %%
plt.imshow(np.array(a)[78:121,211:253,:])

# %%
pic=np.zeros((128,128,16))
pic[:,:,0]=misc.imresize(np.array(a)[37:78,81:123,:], (128, 128))[:,:,0]
pic[:,:,3]=misc.imresize(np.array(a)[80:122,81:123,:], (128, 128))[:,:,0]
pic[:,:,6]=misc.imresize(np.array(a)[126:169,81:123,:], (128, 128))[:,:,0]
pic[:,:,1]=misc.imresize(np.array(a)[34:72,147:187,:], (128, 128))[:,:,0]
pic[:,:,4]=misc.imresize(np.array(a)[79:121,147:190,:], (128, 128))[:,:,0]
pic[:,:,7]=misc.imresize(np.array(a)[125:168,148:190,:], (128, 128))[:,:,0]
pic[:,:,2]=misc.imresize(np.array(a)[34:76,211:253,:], (128, 128))[:,:,0]
pic[:,:,5]=misc.imresize(np.array(a)[78:121,211:253,:], (128, 128))[:,:,0]
pic[:,:,8]=misc.imresize(np.array(a)[241:279,17:55,:], (128, 128))[:,:,0]
pic[:,:,9]=misc.imresize(np.array(a)[240:281,102:144,:], (128, 128))[:,:,0]
pic[:,:,10]=misc.imresize(np.array(a)[240:281,183:225,:], (128, 128))[:,:,0]
pic[:,:,11]=misc.imresize(np.array(a)[239:280,265:306,:], (128, 128))[:,:,0]
pic[:,:,12]=misc.imresize(np.array(a)[312:353,23:65,:], (128, 128))[:,:,0]
pic[:,:,13]=misc.imresize(np.array(a)[311:351,102:144,:], (128, 128))[:,:,0]
pic[:,:,14]=misc.imresize(np.array(a)[310:351,184:226,:], (128, 128))[:,:,0]
pic[:,:,15]=misc.imresize(np.array(a)[309:351,265:307,:], (128, 128))[:,:,0]
for i in range (0,8):
    plt.subplot(3,3,i+1)
    plt.imshow(pic[:,:,i],cmap='gray')
    plt.axis('off')
# Out:
# /Users/sofiadunlosky/miniconda3/envs/mlp/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#
# /Users/sofiadunlosky/miniconda3/envs/mlp/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/sofiadunlosky/miniconda3/envs/mlp/lib/python3.7/site-packages/ipykernel_launcher.py:4: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   after removing the cwd from sys.path.
# ...

# %%
np.save('pic'+N,pic)
